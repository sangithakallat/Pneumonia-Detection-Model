# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Set the image dimensions
img_width, img_height = 224,224

# Set the paths to your training and validation data
train_data_dir = r'C:\Users\Admin\Documents\SEM3\Project\Pneumonia X-Ray Images\train_data'
validation_data_dir = r'C:\Users\Admin\Documents\SEM3\Project\Pneumonia X-Ray Images\val'

# Set the number of samples and epochs
nb_train_samples = 4192
nb_validation_samples = 1040
epochs = 40
batch_size = 16

# Data preprocessing and augmentation
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode='binary')

validation_generator = validation_datagen.flow_from_directory(validation_data_dir, target_size=(img_width, img_height), batch_size=batch_size, class_mode='binary')



model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)))  # convolutional layer (224x224x32)
model.add(MaxPooling2D((2, 2)))  # maxpooling layer (112x112x32)

model.add(Conv2D(64, (3, 3), activation='relu', padding='same'))  # convolutional layer (112x112x64)
model.add(MaxPooling2D((2, 2)))  # maxpooling layer (56x56x64)

model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))  # convolutional layer (56x56x128)
model.add(MaxPooling2D((2, 2)))  # maxpooling layer (28x28x128)

model.add(Conv2D(256, (3, 3), activation='relu', padding='same'))  # convolutional layer (28x28x256)
model.add(Conv2D(128, (3, 3), activation='relu', padding='same'))  # convolutional layer (28x28x128)
model.add(MaxPooling2D((3, 3)))  # maxpooling layer (9x9x128)

model.add(Conv2D(1024, (3, 3), activation='relu', padding='same'))  # convolutional layer (9x9x1024)
model.add(Conv2D(512, (3, 3), activation='relu', padding='same'))  # convolutional layer (9x9x512)
model.add(MaxPooling2D((3, 3)))  # maxpooling layer (3x3x512)

# Flatten the output
model.add(Flatten())

# Add fully connected layers
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))


# Compile the model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_generator, steps_per_epoch=nb_train_samples // batch_size, epochs=epochs, validation_data=validation_generator, validation_steps=nb_validation_samples // batch_size)
# Out:
# Found 4192 images belonging to 2 classes.
# Found 1040 images belonging to 2 classes.
# Epoch 1/40
# 262/262 [==============================] - 1028s 4s/step - loss: 0.4473 - accuracy: 0.7827 - val_loss: 0.2841 - val_accuracy: 0.9038
# Epoch 2/40
# 262/262 [==============================] - 983s 4s/step - loss: 0.2675 - accuracy: 0.8915 - val_loss: 0.2072 - val_accuracy: 0.9317
# Epoch 3/40
# 262/262 [==============================] - 983s 4s/step - loss: 0.2239 - accuracy: 0.9089 - val_loss: 0.2144 - val_accuracy: 0.9250
# Epoch 4/40
# 262/262 [==============================] - 981s 4s/step - loss: 0.2322 - accuracy: 0.9077 - val_loss: 0.1918 - val_accuracy: 0.9375
# Epoch 5/40
# 262/262 [==============================] - 973s 4s/step - loss: 0.1897 - accuracy: 0.9189 - val_loss: 0.1674 - val_accuracy: 0.9452
# Epoch 6/40
# 262/262 [==============================] - 856s 3s/step - loss: 0.1811 - accuracy: 0.9280 - val_loss: 0.1580 - val_accuracy: 0.9404
# Epoch 7/40
# 262/262 [==============================] - 860s 3s/step - loss: 0.1658 - accuracy: 0.9311 - val_loss: 0.1613 - val_accuracy: 0.9433
# Epoch 8/40
# 262/262 [==============================] - 857s 3s/step - loss: 0.1509 - accuracy: 0.9404 - val_loss: 0.1356 - val_accuracy: 0.9529
# Epoch 9/40
# 262/262 [==============================] - 859s 3s/step - loss: 0.1494 - accuracy: 0.9411 - val_loss: 0.1306 - val_accuracy: 0.9538
# Epoch 10/40
# 262/262 [==============================] - 883s 3s/step - loss: 0.1516 - accuracy: 0.9408 - val_loss: 0.1618 - val_accuracy: 0.9394
# Epoch 11/40
# 262/262 [==============================] - 989s 4s/step - loss: 0.1335 - accuracy: 0.9463 - val_loss: 0.1478 - val_accuracy: 0.9423
# Epoch 12/40
# 262/262 [==============================] - 994s 4s/step - loss: 0.1208 - accuracy: 0.9528 - val_loss: 0.1345 - val_accuracy: 0.9596
# Epoch 13/40
# 262/262 [==============================] - 991s 4s/step - loss: 0.1158 - accuracy: 0.9566 - val_loss: 0.1449 - val_accuracy: 0.9538
# Epoch 14/40
# 262/262 [==============================] - 983s 4s/step - loss: 0.1238 - accuracy: 0.9504 - val_loss: 0.1171 - val_accuracy: 0.9692
# Epoch 15/40
# 262/262 [==============================] - 975s 4s/step - loss: 0.1096 - accuracy: 0.9573 - val_loss: 0.1332 - val_accuracy: 0.9615
# Epoch 16/40
# 262/262 [==============================] - 975s 4s/step - loss: 0.1171 - accuracy: 0.9540 - val_loss: 0.1005 - val_accuracy: 0.9596
# Epoch 17/40
# 262/262 [==============================] - 859s 3s/step - loss: 0.1116 - accuracy: 0.9566 - val_loss: 0.1567 - val_accuracy: 0.9548
# Epoch 18/40
# 262/262 [==============================] - 860s 3s/step - loss: 0.1014 - accuracy: 0.9614 - val_loss: 0.1385 - val_accuracy: 0.9519
# Epoch 19/40
# 262/262 [==============================] - 859s 3s/step - loss: 0.1080 - accuracy: 0.9578 - val_loss: 0.1338 - val_accuracy: 0.9577
# Epoch 20/40
# 262/262 [==============================] - 857s 3s/step - loss: 0.0950 - accuracy: 0.9623 - val_loss: 0.1025 - val_accuracy: 0.9606
# Epoch 21/40
# 262/262 [==============================] - 859s 3s/step - loss: 0.0954 - accuracy: 0.9611 - val_loss: 0.1183 - val_accuracy: 0.9548
# Epoch 22/40
# 262/262 [==============================] - 856s 3s/step - loss: 0.1037 - accuracy: 0.9640 - val_loss: 0.1513 - val_accuracy: 0.9538
# Epoch 23/40
# 262/262 [==============================] - 858s 3s/step - loss: 0.1064 - accuracy: 0.9609 - val_loss: 0.1136 - val_accuracy: 0.9596
# Epoch 24/40
# 262/262 [==============================] - 856s 3s/step - loss: 0.0928 - accuracy: 0.9664 - val_loss: 0.1411 - val_accuracy: 0.9481
# Epoch 25/40
# 262/262 [==============================] - 855s 3s/step - loss: 0.0903 - accuracy: 0.9649 - val_loss: 0.1488 - val_accuracy: 0.9538
# Epoch 26/40
# 262/262 [==============================] - 991s 4s/step - loss: 0.0894 - accuracy: 0.9676 - val_loss: 0.1404 - val_accuracy: 0.9567
# Epoch 27/40
# 262/262 [==============================] - 992s 4s/step - loss: 0.0833 - accuracy: 0.9664 - val_loss: 0.1512 - val_accuracy: 0.9548
# Epoch 28/40
# 262/262 [==============================] - 999s 4s/step - loss: 0.0923 - accuracy: 0.9659 - val_loss: 0.1521 - val_accuracy: 0.9606
# Epoch 29/40
# 262/262 [==============================] - 990s 4s/step - loss: 0.0869 - accuracy: 0.9692 - val_loss: 0.1253 - val_accuracy: 0.9538
# Epoch 30/40
# 262/262 [==============================] - 979s 4s/step - loss: 0.0831 - accuracy: 0.9699 - val_loss: 0.1598 - val_accuracy: 0.9394
# Epoch 31/40
# 262/262 [==============================] - 976s 4s/step - loss: 0.0831 - accuracy: 0.9688 - val_loss: 0.1252 - val_accuracy: 0.9510
# Epoch 32/40
# 262/262 [==============================] - 990s 4s/step - loss: 0.0868 - accuracy: 0.9647 - val_loss: 0.1126 - val_accuracy: 0.9577
# Epoch 33/40
# 262/262 [==============================] - 880s 3s/step - loss: 0.0818 - accuracy: 0.9695 - val_loss: 0.1715 - val_accuracy: 0.9596
# Epoch 34/40
# 262/262 [==============================] - 861s 3s/step - loss: 0.0783 - accuracy: 0.9702 - val_loss: 0.1713 - val_accuracy: 0.9462
# Epoch 35/40
# 262/262 [==============================] - 862s 3s/step - loss: 0.0881 - accuracy: 0.9671 - val_loss: 0.1290 - val_accuracy: 0.9510
# Epoch 36/40
# 262/262 [==============================] - 868s 3s/step - loss: 0.0794 - accuracy: 0.9714 - val_loss: 0.1154 - val_accuracy: 0.9596
# Epoch 37/40
# 262/262 [==============================] - 864s 3s/step - loss: 0.0667 - accuracy: 0.9754 - val_loss: 0.0980 - val_accuracy: 0.9663
# Epoch 38/40
# 262/262 [==============================] - 860s 3s/step - loss: 0.0758 - accuracy: 0.9726 - val_loss: 0.0904 - val_accuracy: 0.9606
# Epoch 39/40
# 262/262 [==============================] - 904s 3s/step - loss: 0.0769 - accuracy: 0.9702 - val_loss: 0.1085 - val_accuracy: 0.9625
# Epoch 40/40
# 262/262 [==============================] - 1025s 4s/step - loss: 0.0713 - accuracy: 0.9730 - val_loss: 0.1126 - val_accuracy: 0.9558

# %%
  # Save the model
model.save('C:/Users/Admin/Documents/SEM3/Project/Models/model4.keras')
